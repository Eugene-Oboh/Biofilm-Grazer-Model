# %%
#grazing effect
    
plot1="data/model_runs/scenario_kp10/scenario/p100-g0/biomass_data.nc"
plot2="data/model_runs/scenario_kp10/scenario/p100-g1/biomass_data.nc"
plot3="data/model_runs/scenario_kp10/scenario/p100-g3/biomass_data.nc"
plot4="data/model_runs/scenario_kp10/scenario/p100-g6/biomass_data.nc"
plot5="data/model_runs/scenario_kp10/scenario/p100-g10/biomass_data.nc"
plot6="data/model_runs/scenario_kp10/scenario/p100-g20/biomass_data.nc"
plot7="data/model_runs/scenario_kp10/scenario/p100-g25/biomass_data.nc"
plot8="data/model_runs/scenario_kp10/scenario/p100-g30/biomass_data.nc"
plot9="data/model_runs/scenario_kp10/scenario/p100-g35/biomass_data.nc"
save = "data/model_runs/scenario_kp10/figures/scenario2_grazing.jpg"


import matplotlib.pyplot as plt
import xarray as xr


biomass_grids1 = xr.open_dataarray(plot1)
biomass_grids2 = xr.open_dataarray(plot2)
biomass_grids3 = xr.open_dataarray(plot3)
biomass_grids4 = xr.open_dataarray(plot4)
biomass_grids5 = xr.open_dataarray(plot5)
biomass_grids6 = xr.open_dataarray(plot6)
biomass_grids7 = xr.open_dataarray(plot7)
biomass_grids8 = xr.open_dataarray(plot8)
biomass_grids9 = xr.open_dataarray(plot9)

biomass_grids1.coords['days'] = biomass_grids1['time'] / 1440
biomass_grids2.coords['dayss'] = biomass_grids2['time'] / 1440
biomass_grids3.coords['days'] = biomass_grids3['time'] / 1440
biomass_grids4.coords['dayss'] = biomass_grids4['time'] / 1440
biomass_grids5.coords['days'] = biomass_grids5['time'] / 1440
biomass_grids6.coords['dayss'] = biomass_grids6['time'] / 1440
biomass_grids7.coords['days'] = biomass_grids7['time'] / 1440
biomass_grids8.coords['dayss'] = biomass_grids8['time'] / 1440
biomass_grids9.coords['dayss'] = biomass_grids9['time'] / 1440       


plt.figure()
ax = plt.subplot(111)
#ax2 = plt.twinx(ax)
days =[0, 7, 14,21,28, 35, 42,49, 56]
mark = [0, 336, 672, 1008,1344, 1680,2016,2352, 2688] 
#for i in mark:
lines1 = biomass_grids1.mean(dim=('X', "Y")).plot(ax=ax, x='days', color='C0', markevery=mark, marker="o")
lines2 = biomass_grids2.mean(dim=('X', "Y")).plot(ax=ax, x='dayss', color='C1', markevery=mark, marker="o")
lines3 = biomass_grids3.mean(dim=('X', "Y")).plot(ax=ax, x='days', color='C2', markevery=mark, marker="o")
lines4 = biomass_grids4.mean(dim=('X', "Y")).plot(ax=ax, x='dayss', color='C3', markevery=mark, marker="o")
lines5 = biomass_grids5.mean(dim=('X', "Y")).plot(ax=ax, x='days', color='C4', markevery=mark, marker="o")
lines6 = biomass_grids6.mean(dim=('X', "Y")).plot(ax=ax, x='dayss', color='C5', markevery=mark, marker="o")
lines7 = biomass_grids7.mean(dim=('X', "Y")).plot(ax=ax, x='days', color='C6', markevery=mark, marker="o")
lines8 = biomass_grids8.mean(dim=('X', "Y")).plot(ax=ax, x='dayss', color='C7', markevery=mark, marker="o")
lines9 = biomass_grids9.mean(dim=('X', "Y")).plot(ax=ax, x='dayss', color='C8', markevery=mark, marker="o")


ax.set_ylabel('Mean biomass of grid (mg/cm2)')
#ax2.set_ylabel('StdDev of biomass (mg/mm2)')
ax.set_xlabel('Time (days)')
plt.legend(lines1+lines2+lines3+lines4+lines5+lines6+lines7+lines8+lines9, ['grazer=0', 'grazer=1','grazer=3','grazer=6','grazer=10','grazer=20','grazer=25','grazer=30','grazer=35'])

plt.savefig(save)

# %%
#grazing effect
    
plot1="data/model_runs/scenario_kp10/scenario/p100-g0/biomass_data.nc"
plot2="data/model_runs/scenario_kp10/scenario/p100-g1/biomass_data.nc"
plot3="data/model_runs/scenario_kp10/scenario/p100-g3/biomass_data.nc"
plot4="data/model_runs/scenario_kp10/scenario/p100-g6/biomass_data.nc"
plot5="data/model_runs/scenario_kp10/scenario/p100-g10/biomass_data.nc"
plot6="data/model_runs/scenario_kp10/scenario/p100-g20/biomass_data.nc"
plot7="data/model_runs/scenario_kp10/scenario/p100-g25/biomass_data.nc"
plot8="data/model_runs/scenario_kp10/scenario/p100-g30/biomass_data.nc"
plot9="data/model_runs/scenario_kp10/scenario/p100-g35/biomass_data.nc"
save = "data/model_runs/scenario_kp10/figures/scenario2_grazing.jpg"


import matplotlib.pyplot as plt
import xarray as xr


biomass_grids1 = xr.open_dataarray(plot1)
biomass_grids2 = xr.open_dataarray(plot2)
biomass_grids3 = xr.open_dataarray(plot3)
biomass_grids4 = xr.open_dataarray(plot4)
biomass_grids5 = xr.open_dataarray(plot5)
biomass_grids6 = xr.open_dataarray(plot6)
biomass_grids7 = xr.open_dataarray(plot7)
biomass_grids8 = xr.open_dataarray(plot8)
biomass_grids9 = xr.open_dataarray(plot9)

biomass_grids1.coords['days'] = biomass_grids1['time'] / 1440
biomass_grids2.coords['dayss'] = biomass_grids2['time'] / 1440
biomass_grids3.coords['days'] = biomass_grids3['time'] / 1440
biomass_grids4.coords['dayss'] = biomass_grids4['time'] / 1440
biomass_grids5.coords['days'] = biomass_grids5['time'] / 1440
biomass_grids6.coords['dayss'] = biomass_grids6['time'] / 1440
biomass_grids7.coords['days'] = biomass_grids7['time'] / 1440
biomass_grids8.coords['dayss'] = biomass_grids8['time'] / 1440
biomass_grids9.coords['dayss'] = biomass_grids9['time'] / 1440       


#plt.figure()
#ax = plt.subplot(111)
#ax2 = plt.twinx(ax)
#mark = [336, 672, 1008, 1680, 2688] 
#for i in mark:
lines1 = biomass_grids1.mean(dim=('X', "Y"))
lines2 = biomass_grids2.mean(dim=('X', "Y"))
lines3 = biomass_grids3.mean(dim=('X', "Y"))
lines4 = biomass_grids4.mean(dim=('X', "Y"))
lines5 = biomass_grids5.mean(dim=('X', "Y"))
lines6 = biomass_grids6.mean(dim=('X', "Y"))
lines7 = biomass_grids7.mean(dim=('X', "Y"))
lines8 = biomass_grids8.mean(dim=('X', "Y"))
lines9 = biomass_grids9.mean(dim=('X', "Y"))


G0 =[]
G1 =[]
G3 =[]
G6 =[]
G10 =[]
G20 =[]
G25 =[]
G30 =[]
G35 =[]
days =[0, 7, 14,21,28, 35, 42,49, 56]
for i in days:
    G0.append((lines1[48*i]).item())
    G1.append((lines2[48*i]).item())
    G3.append((lines3[48*i]).item())
    G6.append((lines4[48*i]).item())
    G10.append((lines5[48*i]).item())
    G20.append((lines6[48*i]).item())
    G25.append((lines7[48*i]).item())
    G30.append((lines8[48*i]).item())
    G35.append((lines9[48*i]).item())

#ax.set_ylabel('Mean biomass of grid (mg/cm2)')
#ax2.set_ylabel('StdDev of biomass (mg/mm2)')
#ax.set_xlabel('Time (days)')
#plt.legend(lines1+lines2+lines3+lines4+lines5+lines6+lines7+lines8+lines9, ['grazer=0', 'grazer=1','grazer=3','grazer=6','grazer=10','grazer=20','grazer=25','grazer=30','grazer=35'])

#plt.savefig(save)

# %%
import pandas as pd
data = {'G=0': G0,
        'G=1': G1,
        'G=3': G3,
        'G=6': G6,
        'G=10': G10,
        'G=20': G20,
        'G=25': G25,
        'G=30': G30,
        'G=35': G35}
df = pd.DataFrame(data,columns=['G=0','G=1','G=3','G=6','G=10','G=20','G=25','G=30','G=35'], index = days)

# Multiple bar chart

df.plot.bar(figsize=(10,5))
plt.ylabel('Mean biomass of grid (mg/cm2)')
plt.xlabel('Time (days)')
plt.title('P = 100 µg/L')
plt.savefig("data/model_runs/scenario_kp10/figures/scenario2_grazer_barplot.jpg")
# Display

plt.show()
