# %%
# P2 analysis

plot1 = "data/model_runs/scenario_kp10/scenario/p2-g0/biomass_data.nc"
plot2 = "data/model_runs/scenario_kp10/scenario/p2-g1/biomass_data.nc"
plot3 = "data/model_runs/scenario_kp10/scenario/p2-g3/biomass_data.nc"
plot4= "data/model_runs/scenario_kp10/scenario/p2-g6/biomass_data.nc"
plot5= "data/model_runs/scenario_kp10/scenario/p2-g10/biomass_data.nc"
plot6 = "data/model_runs/scenario_kp10/scenario/p2-g20/biomass_data.nc"
plot7 = "data/model_runs/scenario_kp10/scenario/p2-g25/biomass_data.nc"
plot8 = "data/model_runs/scenario_kp10/scenario/p2-g30/biomass_data.nc"
plot9 = "data/model_runs/scenario_kp10/scenario/p2-g35/biomass_data.nc"
#plot10 = "data/model_runs/scenario/p2-g40/biomass_data.nc"
save = "data/model_runs/scenario_kp10/scenario/figures/p2_compare.jpg"


import matplotlib.pyplot as plt
import xarray as xr

biomass_grids1 = xr.open_dataarray(plot1)
biomass_grids2 = xr.open_dataarray(plot2)
biomass_grids3 = xr.open_dataarray(plot3)
biomass_grids4 = xr.open_dataarray(plot4)
biomass_grids5 = xr.open_dataarray(plot5)
biomass_grids6 = xr.open_dataarray(plot6)
biomass_grids7 = xr.open_dataarray(plot7)
biomass_grids8 = xr.open_dataarray(plot8)
biomass_grids9 = xr.open_dataarray(plot9)
#biomass_grids10 = xr.open_dataarray(plot10)
biomass_grids1.coords['days'] = biomass_grids1['time'] / 1440
biomass_grids2.coords['days'] = biomass_grids2['time'] / 1440
biomass_grids3.coords['days'] = biomass_grids3['time'] / 1440
biomass_grids4.coords['days'] = biomass_grids4['time'] / 1440
biomass_grids5.coords['days'] = biomass_grids5['time'] / 1440
biomass_grids6.coords['days'] = biomass_grids6['time'] / 1440
biomass_grids7.coords['days'] = biomass_grids7['time'] / 1440
biomass_grids8.coords['days'] = biomass_grids8['time'] / 1440
biomass_grids9.coords['days'] = biomass_grids9['time'] / 1440
#biomass_grids10.coords['days'] = biomass_grids10['time'] / 1440

        
plt.figure()
ax = plt.subplot(111)
#ax2 = plt.twinx(ax)
    
lines1 = biomass_grids1.mean(dim=('X', "Y")).plot(ax=ax, x='days', color='C0')
lines2 = biomass_grids2.mean(dim=('X', "Y")).plot(ax=ax,  x='days',color='C1')
lines3 = biomass_grids3.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C2')
lines4 = biomass_grids4.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C3')
lines5 = biomass_grids5.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C4')
lines6 = biomass_grids6.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C5')
lines7 = biomass_grids7.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C3')
lines8 = biomass_grids8.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C4')
lines9 = biomass_grids9.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C5')
ax.set_ylabel('Mean biomass of grid (mg/cm2)')
#ax2.set_ylabel('StdDev of biomass (mg/mm2)')
ax.set_xlabel('Time (days)')
plt.legend(lines1+lines2+lines3+lines4+lines5+lines6+lines7+lines8+lines9, ['grazers=0', 'grazers=1', 'grazers=3', 'grazers=6','grazers=10','grazers=20', 'grazers=25','grazers=30', 'grazers=35'])
plt.title('Nutrient(P)= 2μg/L')
plt.savefig(save)

# %%
#P5
# P2 analysis

plot1 = "data/model_runs/scenario_kp10/scenario/p5-g0/biomass_data.nc"
plot2 = "data/model_runs/scenario_kp10/scenario/p5-g1/biomass_data.nc"
plot3 = "data/model_runs/scenario_kp10/scenario/p5-g3/biomass_data.nc"
plot4= "data/model_runs/scenario_kp10/scenario/p5-g6/biomass_data.nc"
plot5= "data/model_runs/scenario_kp10/scenario/p5-g10/biomass_data.nc"
plot6 = "data/model_runs/scenario_kp10/scenario/p5-g20/biomass_data.nc"
plot7 = "data/model_runs/scenario_kp10/scenario/p5-g25/biomass_data.nc"
plot8 = "data/model_runs/scenario_kp10/scenario/p5-g30/biomass_data.nc"
plot9 = "data/model_runs/scenario_kp10/scenario/p5-g35/biomass_data.nc"
#plot10 = "data/model_runs/scenario/p2-g40/biomass_data.nc"
save = "data/model_runs/scenario_kp10/scenario/figures/p5_compare.jpg"


import matplotlib.pyplot as plt
import xarray as xr

biomass_grids1 = xr.open_dataarray(plot1)
biomass_grids2 = xr.open_dataarray(plot2)
biomass_grids3 = xr.open_dataarray(plot3)
biomass_grids4 = xr.open_dataarray(plot4)
biomass_grids5 = xr.open_dataarray(plot5)
biomass_grids6 = xr.open_dataarray(plot6)
biomass_grids7 = xr.open_dataarray(plot7)
biomass_grids8 = xr.open_dataarray(plot8)
biomass_grids9 = xr.open_dataarray(plot9)
#biomass_grids10 = xr.open_dataarray(plot10)
biomass_grids1.coords['days'] = biomass_grids1['time'] / 1440
biomass_grids2.coords['days'] = biomass_grids2['time'] / 1440
biomass_grids3.coords['days'] = biomass_grids3['time'] / 1440
biomass_grids4.coords['days'] = biomass_grids4['time'] / 1440
biomass_grids5.coords['days'] = biomass_grids5['time'] / 1440
biomass_grids6.coords['days'] = biomass_grids6['time'] / 1440
biomass_grids7.coords['days'] = biomass_grids7['time'] / 1440
biomass_grids8.coords['days'] = biomass_grids8['time'] / 1440
biomass_grids9.coords['days'] = biomass_grids9['time'] / 1440
#biomass_grids10.coords['days'] = biomass_grids10['time'] / 1440

        
plt.figure()
ax = plt.subplot(111)
#ax2 = plt.twinx(ax)
    
lines1 = biomass_grids1.mean(dim=('X', "Y")).plot(ax=ax, x='days', color='C0')
lines2 = biomass_grids2.mean(dim=('X', "Y")).plot(ax=ax,  x='days',color='C1')
lines3 = biomass_grids3.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C2')
lines4 = biomass_grids4.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C3')
lines5 = biomass_grids5.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C4')
lines6 = biomass_grids6.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C5')
lines7 = biomass_grids7.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C3')
lines8 = biomass_grids8.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C4')
lines9 = biomass_grids9.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C5')
ax.set_ylabel('Mean biomass of grid (mg/cm2)')
#ax2.set_ylabel('StdDev of biomass (mg/mm2)')
ax.set_xlabel('Time (days)')
plt.legend(lines1+lines2+lines3+lines4+lines5+lines6+lines7+lines8+lines9, ['grazers=0', 'grazers=1', 'grazers=3', 'grazers=6','grazers=10','grazers=20', 'grazers=25','grazers=30', 'grazers=35'])
plt.title('Nutrient(P)= 5μg/L')
plt.savefig(save)

# %%
# P 10
# P2 analysis

plot1 = "data/model_runs/scenario_kp10/scenario/p10-g0/biomass_data.nc"
plot2 = "data/model_runs/scenario_kp10/scenario/p10-g1/biomass_data.nc"
plot3 = "data/model_runs/scenario_kp10/scenario/p10-g3/biomass_data.nc"
plot4= "data/model_runs/scenario_kp10/scenario/p10-g6/biomass_data.nc"
plot5= "data/model_runs/scenario_kp10/scenario/p10-g10/biomass_data.nc"
plot6 = "data/model_runs/scenario_kp10/scenario/p10-g20/biomass_data.nc"
plot7 = "data/model_runs/scenario_kp10/scenario/p10-g25/biomass_data.nc"
plot8 = "data/model_runs/scenario_kp10/scenario/p10-g30/biomass_data.nc"
plot9 = "data/model_runs/scenario_kp10/scenario/p10-g35/biomass_data.nc"
#plot10 = "data/model_runs/scenario/p2-g40/biomass_data.nc"
save = "data/model_runs/scenario_kp10/scenario/figures/p10_compare.jpg"


import matplotlib.pyplot as plt
import xarray as xr

biomass_grids1 = xr.open_dataarray(plot1)
biomass_grids2 = xr.open_dataarray(plot2)
biomass_grids3 = xr.open_dataarray(plot3)
biomass_grids4 = xr.open_dataarray(plot4)
biomass_grids5 = xr.open_dataarray(plot5)
biomass_grids6 = xr.open_dataarray(plot6)
biomass_grids7 = xr.open_dataarray(plot7)
biomass_grids8 = xr.open_dataarray(plot8)
biomass_grids9 = xr.open_dataarray(plot9)
#biomass_grids10 = xr.open_dataarray(plot10)
biomass_grids1.coords['days'] = biomass_grids1['time'] / 1440
biomass_grids2.coords['days'] = biomass_grids2['time'] / 1440
biomass_grids3.coords['days'] = biomass_grids3['time'] / 1440
biomass_grids4.coords['days'] = biomass_grids4['time'] / 1440
biomass_grids5.coords['days'] = biomass_grids5['time'] / 1440
biomass_grids6.coords['days'] = biomass_grids6['time'] / 1440
biomass_grids7.coords['days'] = biomass_grids7['time'] / 1440
biomass_grids8.coords['days'] = biomass_grids8['time'] / 1440
biomass_grids9.coords['days'] = biomass_grids9['time'] / 1440
#biomass_grids10.coords['days'] = biomass_grids10['time'] / 1440

        
plt.figure()
ax = plt.subplot(111)
#ax2 = plt.twinx(ax)
    
lines1 = biomass_grids1.mean(dim=('X', "Y")).plot(ax=ax, x='days', color='C0')
lines2 = biomass_grids2.mean(dim=('X', "Y")).plot(ax=ax,  x='days',color='C1')
lines3 = biomass_grids3.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C2')
lines4 = biomass_grids4.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C3')
lines5 = biomass_grids5.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C4')
lines6 = biomass_grids6.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C5')
lines7 = biomass_grids7.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C3')
lines8 = biomass_grids8.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C4')
lines9 = biomass_grids9.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C5')
ax.set_ylabel('Mean biomass of grid (mg/cm2)')
#ax2.set_ylabel('StdDev of biomass (mg/mm2)')
ax.set_xlabel('Time (days)')
plt.legend(lines1+lines2+lines3+lines4+lines5+lines6+lines7+lines8+lines9, ['grazers=0', 'grazers=1', 'grazers=3', 'grazers=6','grazers=10','grazers=20', 'grazers=25','grazers=30', 'grazers=35'])
plt.title('Nutrient(P)= 10μg/L')
plt.savefig(save)

# %%
# P15

plot1 = "data/model_runs/scenario_kp10/scenario/p15-g0/biomass_data.nc"
plot2 = "data/model_runs/scenario_kp10/scenario/p15-g1/biomass_data.nc"
plot3 = "data/model_runs/scenario_kp10/scenario/p15-g3/biomass_data.nc"
plot4= "data/model_runs/scenario_kp10/scenario/p15-g6/biomass_data.nc"
plot5= "data/model_runs/scenario_kp10/scenario/p15-g10/biomass_data.nc"
plot6 = "data/model_runs/scenario_kp10/scenario/p15-g20/biomass_data.nc"
plot7 = "data/model_runs/scenario_kp10/scenario/p15-g25/biomass_data.nc"
plot8 = "data/model_runs/scenario_kp10/scenario/p15-g30/biomass_data.nc"
plot9 = "data/model_runs/scenario_kp10/scenario/p15-g35/biomass_data.nc"
#plot10 = "data/model_runs/scenario/p2-g40/biomass_data.nc"
save = "data/model_runs/scenario_kp10/scenario/figures/p15_compare.jpg"


import matplotlib.pyplot as plt
import xarray as xr

biomass_grids1 = xr.open_dataarray(plot1)
biomass_grids2 = xr.open_dataarray(plot2)
biomass_grids3 = xr.open_dataarray(plot3)
biomass_grids4 = xr.open_dataarray(plot4)
biomass_grids5 = xr.open_dataarray(plot5)
biomass_grids6 = xr.open_dataarray(plot6)
biomass_grids7 = xr.open_dataarray(plot7)
biomass_grids8 = xr.open_dataarray(plot8)
biomass_grids9 = xr.open_dataarray(plot9)
#biomass_grids10 = xr.open_dataarray(plot10)
biomass_grids1.coords['days'] = biomass_grids1['time'] / 1440
biomass_grids2.coords['days'] = biomass_grids2['time'] / 1440
biomass_grids3.coords['days'] = biomass_grids3['time'] / 1440
biomass_grids4.coords['days'] = biomass_grids4['time'] / 1440
biomass_grids5.coords['days'] = biomass_grids5['time'] / 1440
biomass_grids6.coords['days'] = biomass_grids6['time'] / 1440
biomass_grids7.coords['days'] = biomass_grids7['time'] / 1440
biomass_grids8.coords['days'] = biomass_grids8['time'] / 1440
biomass_grids9.coords['days'] = biomass_grids9['time'] / 1440
#biomass_grids10.coords['days'] = biomass_grids10['time'] / 1440

        
plt.figure()
ax = plt.subplot(111)
#ax2 = plt.twinx(ax)
    
lines1 = biomass_grids1.mean(dim=('X', "Y")).plot(ax=ax, x='days', color='C0')
lines2 = biomass_grids2.mean(dim=('X', "Y")).plot(ax=ax,  x='days',color='C1')
lines3 = biomass_grids3.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C2')
lines4 = biomass_grids4.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C3')
lines5 = biomass_grids5.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C4')
lines6 = biomass_grids6.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C5')
lines7 = biomass_grids7.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C3')
lines8 = biomass_grids8.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C4')
lines9 = biomass_grids9.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C5')
ax.set_ylabel('Mean biomass of grid (mg/cm2)')
#ax2.set_ylabel('StdDev of biomass (mg/mm2)')
ax.set_xlabel('Time (days)')
plt.legend(lines1+lines2+lines3+lines4+lines5+lines6+lines7+lines8+lines9, ['grazers=0', 'grazers=1', 'grazers=3', 'grazers=6','grazers=10','grazers=20', 'grazers=25','grazers=30', 'grazers=35'])
plt.title('Nutrient(P)= 15μg/L')
plt.savefig(save)

# %%
# P15
# P2 analysis

plot1 = "data/model_runs/scenario_kp10/scenario/p35-g0/biomass_data.nc"
plot2 = "data/model_runs/scenario_kp10/scenario/p35-g1/biomass_data.nc"
plot3 = "data/model_runs/scenario_kp10/scenario/p35-g3/biomass_data.nc"
plot4= "data/model_runs/scenario_kp10/scenario/p35-g6/biomass_data.nc"
plot5= "data/model_runs/scenario_kp10/scenario/p35-g10/biomass_data.nc"
plot6 = "data/model_runs/scenario_kp10/scenario/p35-g20/biomass_data.nc"
plot7 = "data/model_runs/scenario_kp10/scenario/p35-g25/biomass_data.nc"
plot8 = "data/model_runs/scenario_kp10/scenario/p35-g30/biomass_data.nc"
plot9 = "data/model_runs/scenario_kp10/scenario/p35-g35/biomass_data.nc"
#plot10 = "data/model_runs/scenario/p2-g40/biomass_data.nc"
save = "data/model_runs/scenario_kp10/scenario/figures/p35_compare.jpg"


import matplotlib.pyplot as plt
import xarray as xr

biomass_grids1 = xr.open_dataarray(plot1)
biomass_grids2 = xr.open_dataarray(plot2)
biomass_grids3 = xr.open_dataarray(plot3)
biomass_grids4 = xr.open_dataarray(plot4)
biomass_grids5 = xr.open_dataarray(plot5)
biomass_grids6 = xr.open_dataarray(plot6)
biomass_grids7 = xr.open_dataarray(plot7)
biomass_grids8 = xr.open_dataarray(plot8)
biomass_grids9 = xr.open_dataarray(plot9)
#biomass_grids10 = xr.open_dataarray(plot10)
biomass_grids1.coords['days'] = biomass_grids1['time'] / 1440
biomass_grids2.coords['days'] = biomass_grids2['time'] / 1440
biomass_grids3.coords['days'] = biomass_grids3['time'] / 1440
biomass_grids4.coords['days'] = biomass_grids4['time'] / 1440
biomass_grids5.coords['days'] = biomass_grids5['time'] / 1440
biomass_grids6.coords['days'] = biomass_grids6['time'] / 1440
biomass_grids7.coords['days'] = biomass_grids7['time'] / 1440
biomass_grids8.coords['days'] = biomass_grids8['time'] / 1440
biomass_grids9.coords['days'] = biomass_grids9['time'] / 1440
#biomass_grids10.coords['days'] = biomass_grids10['time'] / 1440

        
plt.figure()
ax = plt.subplot(111)
#ax2 = plt.twinx(ax)
    
lines1 = biomass_grids1.mean(dim=('X', "Y")).plot(ax=ax, x='days', color='C0')
lines2 = biomass_grids2.mean(dim=('X', "Y")).plot(ax=ax,  x='days',color='C1')
lines3 = biomass_grids3.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C2')
lines4 = biomass_grids4.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C3')
lines5 = biomass_grids5.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C4')
lines6 = biomass_grids6.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C5')
lines7 = biomass_grids7.mean(dim=('X', "Y")).plot(ax=ax, x='days',color='C3')
lines8 = biomass_grids8.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C4')
lines9 = biomass_grids9.mean(dim=('X', "Y")).plot(ax=ax,x='days',color='C5')
ax.set_ylabel('Mean biomass of grid (mg/cm2)')
#ax2.set_ylabel('StdDev of biomass (mg/mm2)')
ax.set_xlabel('Time (days)')
plt.legend(lines1+lines2+lines3+lines4+lines5+lines6+lines7+lines8+lines9, ['grazers=0', 'grazers=1', 'grazers=3', 'grazers=6','grazers=10','grazers=20', 'grazers=25','grazers=30', 'grazers=35'])
plt.title('Nutrient(P)= 35μg/L')
plt.savefig(save)
